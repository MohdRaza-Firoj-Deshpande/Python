# %%
"""
Importing Modules in Python: Modules and Packages
In Python, modules and packages help organize and reuse code. 
Here's a comprehensive guide on how to import them.
"""
import numpy as np

import math
check =math.sqrt(10)
print(f"Square Root {check}")


from math import sqrt,pi
print(pi)
# Out:
# Square Root 3.1622776601683795
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import package.maths

# %%
from package.maths import addition
addition(5,6)
# Out:
# 11

# %%
# Out:
# def addition(a,b):
#     return a+b
#
#
#
# def addition(a, b):   # matches 'addition'
#     return a + b

# %%
import importlib
import package.maths
importlib.reload(package.maths)

from package.maths import addition
print(addition(5, 6))
# Out:
# 11
