# %%
"""
Standard Library Overview
Python's Standard Library is a vast collection of modules and 
packages that come bundled with Python, providing a wide range of 
functionalities out of the box. Here's an overview of some of the most 
commonly used modules and packages in the Python Standard Library.

"""

# %%
import array
arr=array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(6))
print(math.pi)
# Out:
# 2.449489742783178
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choices(['apple','banana','cherry']))
# Out:
# 1
# ['apple']

# %%
### File And Directory Access

import os
print(os.getcwd())
# Out:
# e:\1.1.Main\Main\5. Modules

# %%
import os
os.mkdir('test_dir')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.mkdir('test_dir')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test_dir'

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('example.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data ={'name':'krish','age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

load= json.loads(json_str)
print(load)
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>
# {'name': 'krish', 'age': 25}

# %%
import csv
with open('example.csv',mode='w',newline='')as file:
    writer=csv.writer(file)
    writer.writerow(['name','jhon'])
    writer.writerow(['school','sas'])

with open('example.csv',mode='r')as file:
    reader=csv.reader(file)
    for i in reader:
        print(i)
# Out:
# ['name', 'jhon']
# ['school', 'sas']

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-07 21:39:33.099667
# 2026-04-06 21:39:33.099667

# %%
import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1775578274.958879
# 1775578276.9599586

# %%
## Regular expresiion
import re

## Regular expresiion
import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

# %%
"""
Conclusion
Python's Standard Library is extensive and provides tools for almost any task you can think of,
 from file handling to web services, from data serialization to concurrent execution. Familiarizing yourself with the modules 
 and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs. 
"""
